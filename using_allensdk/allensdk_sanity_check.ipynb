# %% [markdown]
# This notebook, `allensdk_sanity_check.ipynb`, is a trivial sanity checker to confirm that [`AllenSDK`](https://github.com/AllenInstitute/AllenSDK) is installed and working within a machine. This can be quite useful on Colab (and the like) where VMs are getting tossed away on a regular, frequent schedule. Just run this notebook and if `data` is an array and there are no errors, one can assume `AllenSDK` is a happy camper.

# %%
from allensdk.api.queries.rma_api import RmaApi

rma = RmaApi()
data = rma.model_query('Atlas', criteria="[name$il'*Mouse*']")
data
# Out:
# [{'description': 'Developing Mouse E15.5 (2010)',
#   'id': 112953467,
#   'image_type': None,
#   'name': 'Developing Mouse, E15.5 (2010)',
#   'reference_space_id': 3,
#   'specimen_id': 6207,
#   'structure_graph_id': None,
#   'treatment_id': 8,
#   'xyz_sort': 'xyz'},
#  {'description': 'Developing Mouse E18.5',
#   'id': 181276160,
#   'image_type': 'Atlas - Developing Mouse',
#   'name': 'Developing Mouse, E18.5',
#   'reference_space_id': 5,
#   'specimen_id': 4981,
#   'structure_graph_id': 17,
#   'treatment_id': 3,
#   'xyz_sort': 'xyz'},
#  {'description': 'Developing Mouse E13.5 (2010)',
#   'id': 112953466,
#   'image_type': None,
#   'name': 'Developing Mouse, E13.5 (2010)',
#   'reference_space_id': 2,
#   'specimen_id': 6206,
#   'structure_graph_id': None,
#   'treatment_id': 8,
#   'xyz_sort': 'xyz'},
#  {'description': 'Developing Mouse E13.5',
#   'id': 181276130,
#   'image_type': 'Atlas - Developing Mouse',
#   'name': 'Developing Mouse, E13.5',
# ...
